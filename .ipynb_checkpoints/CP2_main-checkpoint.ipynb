# %% [markdown]
# # __Problem Statement__
#
# - In modern 5G networks, users expect high-quality video streaming with minimal buffering, low latency, and stable connectivity. However, network performance is affected by multiple factors such as download speed, latency, jitter, congestion level, and dropped connections.
#
# - The challenge is that network quality is dynamic and difficult to evaluate manually in real-time. Service providers need an intelligent system that can predict video streaming quality based on network conditions to improve user experience and optimize network performance.

# %% [markdown]
# ### Steps to be followed:
# 1. Import the required library
# 2. Load the data
# 3. Check for null values
# 4. Analyze the data column distribution
# 5. Balance the data
# 6. Encode of the full dataset
# 7. Split and train the dataset
# 8. Perform feature scaling on the dataset
# 9. Compile the model
# 10. Fit the model
# 11. Print the model
# 12. Evaluate the metrics

# %% [markdown]
# ## Step 1: Import the Required Library
# - Import the essential libraries for data manipulation and analysis, such as NumPy and Pandas, and use PyMySQL for database connectivity, LabelEncoder for data preprocessing, and Matplotlib for visualization

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt



from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score
from sklearn.preprocessing import label_binarize
from sklearn.preprocessing import LabelEncoder,StandardScaler

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Step 2: Load the Data
# - Load a CSV file named **loan_data.xlsx** into a Pandas DataFrame named **df1**
# - Display the initial few rows of the **df1** DataFrame

# %%
df1 = pd.read_csv(r"C:\Users\kpasw\OneDrive\Desktop\CP 2\5g_network_data.csv")
df1
# Out:
#             Location  Signal Strength (dBm)  Download Speed (Mbps)  \
# 0      San Francisco                 -108.6                 714.94
# 1      San Francisco                  -71.5                 686.69
# 2            Chennai                  -76.1                 428.14
# 3           New York                  -73.3                 208.56
# 4            Kolkata                  -93.2                 409.85
# ...              ...                    ...                    ...
# 20562          Tokyo                  -94.2                 770.26
# 20563         Berlin                  -81.1                 984.29
# 20564          Delhi                  -76.6                 480.16
# 20565        Kolkata                  -62.2                 851.07
# 20566         Mumbai                 -106.3                 178.18
#
#        Upload Speed (Mbps)  Latency (ms)  Jitter (ms) Network Type  \
# 0                    60.41          10.0         4.09       5G NSA
# ...

# %%
drop_cols = [
    "Device Model",
    "Temperature (°C)",
    "Battery Level (%)",
    "Connected Duration (min)",
    "Data Usage (MB)",
    "Ping to Google (ms)",
    "Handover Count",
    "Carrier",
    "Band",
    "Location",
    "Network Type"
]

df = df1.drop(columns=drop_cols, errors="ignore")

# %%
df
# Out:
#        Signal Strength (dBm)  Download Speed (Mbps)  Upload Speed (Mbps)  \
# 0                     -108.6                 714.94                60.41
# 1                      -71.5                 686.69               148.70
# 2                      -76.1                 428.14                74.00
# 3                      -73.3                 208.56                68.59
# 4                      -93.2                 409.85               137.23
# ...                      ...                    ...                  ...
# 20562                  -94.2                 770.26                57.62
# 20563                  -81.1                 984.29               124.55
# 20564                  -76.6                 480.16               102.38
# 20565                  -62.2                 851.07                78.59
# 20566                 -106.3                 178.18               146.06
#
#        Latency (ms)  Jitter (ms)  Video Streaming Quality VoNR Enabled  \
# ...

# %% [markdown]
# ## Step 3:Data Cleaning and Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20567 entries, 0 to 20566
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Signal Strength (dBm)     20567 non-null  float64
#  1   Download Speed (Mbps)     20329 non-null  float64
#  2   Upload Speed (Mbps)       20567 non-null  float64
#  3   Latency (ms)              20567 non-null  float64
#  4   Jitter (ms)               20567 non-null  float64
#  5   Video Streaming Quality   20567 non-null  int64
#  6   VoNR Enabled              20450 non-null  object
#  7   Network Congestion Level  20280 non-null  object
#  8   Dropped Connection        20567 non-null  bool
# dtypes: bool(1), float64(5), int64(1), object(2)
# memory usage: 1.3+ MB

# %%
df.isna().sum()
# Out:
# Signal Strength (dBm)         0
# Download Speed (Mbps)       238
# Upload Speed (Mbps)           0
# Latency (ms)                  0
# Jitter (ms)                   0
# Video Streaming Quality       0
# VoNR Enabled                117
# Network Congestion Level    287
# Dropped Connection            0
# dtype: int64

# %%
# df['Download Speed (Mbps)'] = df['Download Speed (Mbps)'].fillna(df['col'].median())
# df['VoNR Enabled'] = df['col'].fillna(df['col'].mode()[0])
df = df.dropna()

# %% [markdown]
# ## Step 4: Exploratory Data Analysis (EDA)
# - Visualizations are used to understand relationships between variables and battery health.

# %%
df.groupby('Network Congestion Level')['Download Speed (Mbps)'].mean().plot(kind='bar')
plt.title("Avg Download Speed by Congestion Level")
plt.ylabel("Download Speed (Mbps)")
plt.show()

# %% [markdown]
# ## Conclusion:
# - The graph shows that average download speed is nearly the same across low, medium, and high congestion levels. This indicates that congestion does not significantly impact download speed in this dataset. Other factors like latency, jitter, or connection stability may play a more important role in determining overall network performance and user experience.

# %%
df.groupby('Dropped Connection')['Signal Strength (dBm)'].mean().plot(kind='bar')
plt.title("Signal Strength vs Dropped Connection")
plt.show()

# %% [markdown]
# ## Conclusion:
# - The graph shows that average signal strength is nearly the same for both dropped and non-dropped connections. This suggests that signal strength alone is not a key factor causing dropped connections.

# %%
sns.boxplot(x='Video Streaming Quality', y='Download Speed (Mbps)', data=df)
plt.title("Video Quality vs Download Speed")
plt.show()

# %% [markdown]
# ## Conclusion:
# - The boxplot shows that download speed distributions are similar across all video quality levels, with only slight increases at higher quality levels. This indicates that while higher speeds may support better video quality, download speed alone is not the only determining factor, and other parameters also influence streaming quality significantly.

# %%
sns.countplot(x='Dropped Connection', data=df)
plt.title("Dropped Connection Count")
plt.show()

# %% [markdown]
# ## Conclusion:
# The count plot shows that dropped and non-dropped connections are almost equally distributed in the dataset. This indicates a balanced target variable, which is beneficial for model training. It ensures that the model does not become biased toward one class and can accurately predict both dropped and stable connections.

# %% [markdown]
# ## Final Conclusion:
# - This project successfully builds a predictive system that can estimate video streaming quality using real-time network parameters.

# %%
congestion_map = {"Low":1, "Medium":2, "High":3}
df["Congestion_Num"] = df["Network Congestion Level"].map(congestion_map)

df["Quality_Score"] = (
    (df["Download Speed (Mbps)"] * 0.5)
    - (df["Latency (ms)"] * 0.2)
    - (df["Jitter (ms)"] * 0.1)
    - (df["Congestion_Num"] * 5)
    - (df["Dropped Connection"].astype(int) * 20)
)

df["Video Streaming Quality"] = df["Video Streaming Quality"].astype(int)

df["Video Streaming Quality"] = pd.qcut(
    df["Quality_Score"],
    q=5,
    labels=[1,2,3,4,5]
).astype(int)

df.drop(["Quality_Score","Congestion_Num"], axis=1, inplace=True)

# %%
le = LabelEncoder()
df['VoNR Enabled'] = le.fit_transform(df['VoNR Enabled'])
df['Network Congestion Level'] = le.fit_transform(df['Network Congestion Level'])
df['Dropped Connection'] = le.fit_transform(df['Dropped Connection'])

# %%
# x=df.drop('Video Streaming Quality',axis=1)
# y=["Video Streaming Quality"]

# %%
features = [
    "Signal Strength (dBm)",
    "Download Speed (Mbps)",
    "Latency (ms)",
    "Jitter (ms)",
    "VoNR Enabled",
    "Dropped Connection"
]

x=df[features]
y=df["Video Streaming Quality"]

# %%
# x=pd.get_dummies(x, drop_first=True)

x_train, x_test, y_train, y_test = train_test_split(
    x, y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train.shape
# Out:
# (15953, 6)

# %%
x_test.shape
# Out:
# (3989, 6)

# %%
y_train.shape
# Out:
# (15953,)

# %%
y_test.shape
# Out:
# (3989,)

# %%
models = {
    "SVC": SVC(),
    "DecisionTree": DecisionTreeClassifier(),
    "RandomForest": RandomForestClassifier(),
    "XGBoost": XGBClassifier()
}

results = {}

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

results = {}

for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    
    # For ROC-AUC, need probability estimates (not all classifiers support predict_proba)
    if hasattr(model, "predict_proba"):
        y_proba = model.predict_proba(x_test)[:, 1]
        roc_auc = roc_auc_score(y_test, y_proba)
    else:
        roc_auc = None
    
    results[name] = {
        "Accuracy": accuracy_score(y_test, y_pred),
        "Precision": precision_score(y_test, y_pred, average="weighted"),
        "Recall": recall_score(y_test, y_pred, average="weighted"),
        "F1": f1_score(y_test, y_pred, average="weighted"),
        "ROC_AUC": roc_auc
    }

results_df = pd.DataFrame(results).T
results_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 12
#      10 if hasattr(model, "predict_proba"):
#      11     y_proba = model.predict_proba(x_test)[:, 1]
# ---> 12     roc_auc = roc_auc_score(y_test, y_proba)
#      13 else:
#      14     roc_auc = None
#
# File ~\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
# ...

# %%
rf = RandomForestClassifier(random_state=42)

# %%
rf=rf.fit(x_train, y_train)

# %%
y_pred = rf.predict(x_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.966658310353472
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.98       798
#            2       0.97      0.96      0.96       797
#            3       0.96      0.96      0.96       798
#            4       0.96      0.95      0.95       798
#            5       0.98      0.98      0.98       798
#
#     accuracy                           0.97      3989
#    macro avg       0.97      0.97      0.97      3989
# weighted avg       0.97      0.97      0.97      3989

# %%
param_dist = {
    'n_estimators': [300,400,500],
    'max_depth': [None,20,30],
    'min_samples_split': [2,5,10],
    'min_samples_leaf': [1,2,4],
    'max_features': ['sqrt','log2']
}

rs= RandomizedSearchCV(
    rf,
    param_distributions=param_dist,
    n_iter=15,
    cv=5,
    n_jobs=-1,
    random_state=42
)

# %%
rs.fit(x_train, y_train)
best_rf = rs.best_estimator_
print("Best Parameters:", rs.best_params_)
# Out:
# Best Parameters: {'n_estimators': 300, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None}

# %%
y_pred = best_rf.predict(x_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9661569315617949
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.98       798
#            2       0.96      0.96      0.96       797
#            3       0.96      0.96      0.96       798
#            4       0.96      0.95      0.95       798
#            5       0.98      0.98      0.98       798
#
#     accuracy                           0.97      3989
#    macro avg       0.97      0.97      0.97      3989
# weighted avg       0.97      0.97      0.97      3989

# %%
classes = np.unique(y)
y_test_bin = label_binarize(y_test, classes=classes)
y_score = best_rf.predict_proba(x_test)

roc_auc = roc_auc_score(y_test_bin, y_score, multi_class='ovr')

print("Multi-class ROC-AUC:", roc_auc)
# Out:
# Multi-class ROC-AUC: 0.9990683597821228

# %%
import pickle
pickle.dump(best_rf,open('model.pkl','wb'))

# %%
df['Video Streaming Quality'].value_counts()
# Out:
# Video Streaming Quality
# 1    3989
# 5    3989
# 4    3988
# 2    3988
# 3    3988
# Name: count, dtype: int64

# %%
best_rf.score(x_test, y_test)
# Out:
# 0.9661569315617949

# %%
print(x.columns.tolist())
# Out:
# ['Signal Strength (dBm)', 'Download Speed (Mbps)', 'Latency (ms)', 'Jitter (ms)', 'VoNR Enabled', 'Dropped Connection']

# %%
pip install --upgrade scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
print("Test inside notebook:")
print(best_rf.predict([[-65, 250, 10, 2, 1, 0]]))
# Out:
# Test inside notebook:
# [1]

# %%
df['Signal Strength (dBm)'].value_counts()
# Out:
# Signal Strength (dBm)
# -74.8     60
# -62.6     58
# -100.1    57
# -61.2     55
# -64.1     55
#           ..
# -109.7    26
# -92.2     25
# -110.0    23
# -60.0     22
# -71.3     21
# Name: count, Length: 501, dtype: int64

# %%
df['Download Speed (Mbps)'].value_counts()
# Out:
# Download Speed (Mbps)
# 693.07    4
# 760.17    4
# 202.72    4
# 259.97    4
# 297.72    4
#          ..
# 446.54    1
# 672.36    1
# 369.68    1
# 291.10    1
# 178.18    1
# Name: count, Length: 17869, dtype: int64

# %% [markdown]
# # __Applyed XGBoost Classifier__

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier

# %%
y_train = y_train - y_train.min()
y_test = y_test - y_test.min()

# %%
y_train
# Out:
# 803      0
# 19354    4
# 3093     4
# 12972    2
# 413      0
#         ..
# 17406    1
# 13393    2
# 17524    0
# 14570    1
# 2213     2
# Name: Video Streaming Quality, Length: 15953, dtype: int32

# %%
# Create model
xgb_model = XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=5,
    random_state=42,
    use_label_encoder=False,
    eval_metric='logloss'
)

# Train model
xgb_model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
y_train_enc = encoder.fit_transform(y_train)
y_test_enc = encoder.transform(y_test)

xgb_model.fit(x_train, y_train_enc)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred=xgb_model.predict(x_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9676610679368263
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       798
#            1       0.96      0.96      0.96       797
#            2       0.96      0.96      0.96       798
#            3       0.96      0.96      0.96       798
#            4       0.98      0.98      0.98       798
#
#     accuracy                           0.97      3989
#    macro avg       0.97      0.97      0.97      3989
# weighted avg       0.97      0.97      0.97      3989

# %%
import pickle
pickle.dump(xgb_model,open('model.pkl','wb'))
